# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
print(api_key)
# Out:
# sk-your_key_here

# %%
# !python3 langchain_mlflow_RAG.py
# Out:
# Call volume forecasting could help a benefits company by enabling staffing teams to predict busy days in claims call centers, ensuring that they have the appropriate number of staff available to handle the volume of calls efficiently. This can lead to improved customer service and reduced wait times for clients.
# 🏃 View run tiny_langchain_rag_test at: http://127.0.0.1:5001/#/experiments/6/runs/b32dec6fd96a453fb7f632ba86d5d1b4
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/6
# 2026/05/14 21:54:20 INFO mlflow.tracing.export.async_export_queue: Flushing the async trace logging queue before program exit. This may take a while...

# %%
# !pip install mlflow langchain langchain-openai langchain-community langchain-chroma chromadb
